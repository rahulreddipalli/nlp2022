# %%
import pandas as pd

intents = pd.read_csv('intents.csv', header=0)

# %%
intents = intents.sample(len(intents))
intents
# Out:
#                                                   query       intent
# 968                             nice talking again, bye      goodbye
# 388                                    the answer is no           no
# 1027                        i had fun speaking with you      goodbye
# 731             who is the current captain of this ship          oos
# 557                           how did i feel yesterday?  entry_query
# ...                                                 ...          ...
# 895           tell me the amount of calories in muffins          oos
# 663   where can i find the cruise control on my kia ...          oos
# 849                      what is the weather in atlanta          oos
# 1034                                    i'm outta here!      goodbye
# 827            what do you think our purpose is in life          oos
#
# [1052 rows x 2 columns]

# %%
labels = intents.intent.unique()

# %%
print(labels)
# Out:
# ['goodbye' 'no' 'oos' 'entry_query' 'yes' 'add_entry' 'greeting']

# %%
import string

def lower(text):
    result = " ".join([word.lower() for word in text.split()])
    return result

def remove_punc(text):
    remove = str.maketrans('', '', (string.punctuation + '£'))
    return text.translate(remove)

def remove_nums(text):
    remove = str.maketrans('', '', string.digits)
    return text.translate(remove)

# %%
intents['query'] = intents['query'].astype(str)
intents['query'] = intents['query'].apply(lower)
intents['query'] = intents['query'].apply(remove_punc)
intents['query'] = intents['query'].apply(remove_nums)

# %%
labels
# Out:
# array(['goodbye', 'no', 'oos', 'entry_query', 'yes', 'add_entry',
#        'greeting'], dtype=object)

# %%
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
import numpy as np

encoder = LabelEncoder()
encoder.fit(labels)

Y_train = encoder.transform(intents['intent'])

n_classes = np.max(Y_train) + 1

Y_train = np_utils.to_categorical(Y_train, n_classes)

label_names=encoder.classes_

# %%
import matplotlib.pyplot as plt

# %%
def train_val_graph(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+metric])

    plt.title(f'History of {metric} over epochs')
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(['training '+metric, 'validation '+metric])

    plt.show()

# %%
max_len = 128

# %%
from keras.layers import TextVectorization

vectorizer = TextVectorization(output_sequence_length=max_len)

vectorizer.adapt(intents['query'])

vocab = vectorizer.get_vocabulary()

word_index = dict(zip(vocab, range(len(vocab))))

X_train = vectorizer(intents['query'])

# %%
from gensim.models.fasttext import FastText
from gensim.test.utils import datapath

# %%
cor_path = datapath("lee_background.cor")

ft = FastText(vector_size=100)

train_ft = intents['query'].tolist()

train_ft = [x.split() for x in train_ft]

ft.build_vocab(corpus_file=cor_path)

ft.train(
    corpus_file=cor_path, epochs=ft.epochs,
    total_examples=ft.corpus_count, total_words=ft.corpus_total_words,
)

ft.build_vocab(train_ft, update=True)
ft.train(train_ft, total_examples=len(train_ft), epochs=ft.epochs)
# Out:
# (14302, 29825)

# %%
n_tokens = len(vocab) + 2
embedding_dim = 100
hits = 0
misses = 0

matrix = np.zeros((n_tokens, embedding_dim))

for word, i in word_index.items():
    try:
        embedding_vector = ft.wv[word]

        if embedding_vector is not None:
            matrix[i] = embedding_vector
            hits += 1
        else:
            matrix[i] = np.random.randn(embedding_dim)
            misses += 1
    except Exception as e:
        matrix[i] = np.random.randn(embedding_dim)
        print(e)
        misses += 1

print("Converted %d words (%d misses)" % (hits, misses))
# Out:
# Converted 914 words (0 misses)

# %%
from tensorflow import keras
import keras.layers as l
import tensorflow as tf

# %%
inputs = keras.Input(shape=(max_len,))

embedding_layer = l.Embedding(
    n_tokens,
    embedding_dim,
    input_length=max_len,
    embeddings_initializer=tf.keras.initializers.Constant(matrix),
    trainable=True
)(inputs)

reshape = l.Reshape((max_len, 100, 1))(embedding_layer)

conv_0 = l.Conv2D(100, kernel_size=(3, 100), activation='relu')(reshape)
conv_1 = l.Conv2D(100, kernel_size=(4, 100), activation='relu')(reshape)
conv_2 = l.Conv2D(100, kernel_size=(5, 100), activation='relu')(reshape)

maxpool_0 = l.MaxPooling2D(pool_size=(max_len - 3 + 1, 1))(conv_0)
maxpool_1 = l.MaxPooling2D(pool_size=(max_len - 4 + 1, 1))(conv_1)
maxpool_2 = l.MaxPooling2D(pool_size=(max_len - 5 + 1, 1))(conv_2)

concatenate = l.Concatenate(axis=1)([maxpool_0, maxpool_1, maxpool_2])

flatten = l.Flatten()(concatenate)

dropout = l.Dropout(0.5)(flatten)

output = l.Dense(n_classes, activation='softmax')(dropout)

model = keras.Model(inputs=inputs, outputs=output)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

mc = ModelCheckpoint(
    'intents.h5',
    monitor='val_loss',
    verbose=0,
    save_best_only=True,
    mode='auto',
    save_weights_only=False,
    period=1
)

es = EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=50,
    mode='auto'
)

rlr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.8,
    patience=20,
    min_delta=0.001,
    verbose=1, 
    mode='auto'
)

callbacks = [mc, es, rlr]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
optim = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(
    loss="categorical_crossentropy", optimizer=optim, metrics=['accuracy']
)

# %%
hist = model.fit(X_train, Y_train, epochs=200, shuffle=True, validation_split = 0.10, callbacks=callbacks)
# Out:
# Epoch 1/200
# 30/30 [==============================] - 9s 17ms/step - loss: 1.8330 - accuracy: 0.2865 - val_loss: 1.7641 - val_accuracy: 0.3113 - lr: 1.0000e-04
# Epoch 2/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.7818 - accuracy: 0.2992 - val_loss: 1.7419 - val_accuracy: 0.3113 - lr: 1.0000e-04
# Epoch 3/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.7630 - accuracy: 0.3224 - val_loss: 1.7269 - val_accuracy: 0.4057 - lr: 1.0000e-04
# Epoch 4/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.7348 - accuracy: 0.3467 - val_loss: 1.7094 - val_accuracy: 0.4151 - lr: 1.0000e-04
# Epoch 5/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.7224 - accuracy: 0.3488 - val_loss: 1.6931 - val_accuracy: 0.3962 - lr: 1.0000e-04
# Epoch 6/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.7094 - accuracy: 0.3594 - val_loss: 1.6835 - val_accuracy: 0.4151 - lr: 1.0000e-04
# Epoch 7/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.6790 - accuracy: 0.3584 - val_loss: 1.6749 - val_accuracy: 0.4151 - lr: 1.0000e-04
# Epoch 8/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.6703 - accuracy: 0.3658 - val_loss: 1.6737 - val_accuracy: 0.4151 - lr: 1.0000e-04
# Epoch 9/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.6653 - accuracy: 0.3668 - val_loss: 1.6609 - val_accuracy: 0.4151 - lr: 1.0000e-04
# Epoch 10/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.6616 - accuracy: 0.3636 - val_loss: 1.6555 - val_accuracy: 0.4057 - lr: 1.0000e-04
# Epoch 11/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.6426 - accuracy: 0.3658 - val_loss: 1.6365 - val_accuracy: 0.4151 - lr: 1.0000e-04
# Epoch 12/200
# 30/30 [==============================] - 0s 8ms/step - loss: 1.6280 - accuracy: 0.3679 - val_loss: 1.6346 - val_accuracy: 0.4151 - lr: 1.0000e-04
# Epoch 13/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.6095 - accuracy: 0.3700 - val_loss: 1.6250 - val_accuracy: 0.4057 - lr: 1.0000e-04
# Epoch 14/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.6238 - accuracy: 0.3784 - val_loss: 1.6151 - val_accuracy: 0.4151 - lr: 1.0000e-04
# Epoch 15/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.5881 - accuracy: 0.3721 - val_loss: 1.6062 - val_accuracy: 0.4057 - lr: 1.0000e-04
# Epoch 16/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.5903 - accuracy: 0.3837 - val_loss: 1.5919 - val_accuracy: 0.4151 - lr: 1.0000e-04
# Epoch 17/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.5666 - accuracy: 0.3901 - val_loss: 1.5811 - val_accuracy: 0.4057 - lr: 1.0000e-04
# Epoch 18/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.5560 - accuracy: 0.4070 - val_loss: 1.5598 - val_accuracy: 0.4245 - lr: 1.0000e-04
# Epoch 19/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.5360 - accuracy: 0.4207 - val_loss: 1.5550 - val_accuracy: 0.4340 - lr: 1.0000e-04
# Epoch 20/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.5048 - accuracy: 0.4281 - val_loss: 1.5347 - val_accuracy: 0.4811 - lr: 1.0000e-04
# Epoch 21/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.4742 - accuracy: 0.4376 - val_loss: 1.5209 - val_accuracy: 0.4717 - lr: 1.0000e-04
# Epoch 22/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.4538 - accuracy: 0.4493 - val_loss: 1.5019 - val_accuracy: 0.4811 - lr: 1.0000e-04
# Epoch 23/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.4487 - accuracy: 0.4493 - val_loss: 1.4766 - val_accuracy: 0.4811 - lr: 1.0000e-04
# Epoch 24/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.4199 - accuracy: 0.4725 - val_loss: 1.4605 - val_accuracy: 0.5189 - lr: 1.0000e-04
# Epoch 25/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.3931 - accuracy: 0.4789 - val_loss: 1.4517 - val_accuracy: 0.5377 - lr: 1.0000e-04
# Epoch 26/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.3684 - accuracy: 0.4947 - val_loss: 1.4122 - val_accuracy: 0.5472 - lr: 1.0000e-04
# Epoch 27/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.3373 - accuracy: 0.5032 - val_loss: 1.3925 - val_accuracy: 0.5283 - lr: 1.0000e-04
# Epoch 28/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.3079 - accuracy: 0.5201 - val_loss: 1.3705 - val_accuracy: 0.5943 - lr: 1.0000e-04
# Epoch 29/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.2846 - accuracy: 0.5666 - val_loss: 1.3432 - val_accuracy: 0.5849 - lr: 1.0000e-04
# Epoch 30/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.2750 - accuracy: 0.5539 - val_loss: 1.3162 - val_accuracy: 0.5755 - lr: 1.0000e-04
# Epoch 31/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.2127 - accuracy: 0.5877 - val_loss: 1.2854 - val_accuracy: 0.6038 - lr: 1.0000e-04
# Epoch 32/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.2060 - accuracy: 0.5983 - val_loss: 1.2648 - val_accuracy: 0.6321 - lr: 1.0000e-04
# Epoch 33/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.1784 - accuracy: 0.5951 - val_loss: 1.2350 - val_accuracy: 0.6509 - lr: 1.0000e-04
# Epoch 34/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.1498 - accuracy: 0.6247 - val_loss: 1.2162 - val_accuracy: 0.6321 - lr: 1.0000e-04
# Epoch 35/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.1160 - accuracy: 0.6300 - val_loss: 1.1806 - val_accuracy: 0.6509 - lr: 1.0000e-04
# Epoch 36/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.0840 - accuracy: 0.6448 - val_loss: 1.1554 - val_accuracy: 0.6698 - lr: 1.0000e-04
# Epoch 37/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.0473 - accuracy: 0.6734 - val_loss: 1.1373 - val_accuracy: 0.6792 - lr: 1.0000e-04
# Epoch 38/200
# 30/30 [==============================] - 0s 7ms/step - loss: 1.0256 - accuracy: 0.6660 - val_loss: 1.1026 - val_accuracy: 0.6887 - lr: 1.0000e-04
# Epoch 39/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9973 - accuracy: 0.7051 - val_loss: 1.0832 - val_accuracy: 0.6981 - lr: 1.0000e-04
# Epoch 40/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9723 - accuracy: 0.6882 - val_loss: 1.0580 - val_accuracy: 0.7170 - lr: 1.0000e-04
# Epoch 41/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9553 - accuracy: 0.7093 - val_loss: 1.0358 - val_accuracy: 0.7264 - lr: 1.0000e-04
# Epoch 42/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.9238 - accuracy: 0.7273 - val_loss: 1.0089 - val_accuracy: 0.7358 - lr: 1.0000e-04
# Epoch 43/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.8896 - accuracy: 0.7452 - val_loss: 0.9844 - val_accuracy: 0.7358 - lr: 1.0000e-04
# Epoch 44/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8762 - accuracy: 0.7378 - val_loss: 0.9592 - val_accuracy: 0.7358 - lr: 1.0000e-04
# Epoch 45/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8485 - accuracy: 0.7537 - val_loss: 0.9377 - val_accuracy: 0.7453 - lr: 1.0000e-04
# Epoch 46/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.8121 - accuracy: 0.7801 - val_loss: 0.9111 - val_accuracy: 0.7642 - lr: 1.0000e-04
# Epoch 47/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.7895 - accuracy: 0.7865 - val_loss: 0.8910 - val_accuracy: 0.7547 - lr: 1.0000e-04
# Epoch 48/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.7658 - accuracy: 0.7791 - val_loss: 0.8693 - val_accuracy: 0.7736 - lr: 1.0000e-04
# Epoch 49/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.7489 - accuracy: 0.7854 - val_loss: 0.8502 - val_accuracy: 0.7642 - lr: 1.0000e-04
# Epoch 50/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.7191 - accuracy: 0.8087 - val_loss: 0.8295 - val_accuracy: 0.8019 - lr: 1.0000e-04
# Epoch 51/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.7154 - accuracy: 0.8066 - val_loss: 0.8082 - val_accuracy: 0.7925 - lr: 1.0000e-04
# Epoch 52/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.6971 - accuracy: 0.8224 - val_loss: 0.7889 - val_accuracy: 0.8113 - lr: 1.0000e-04
# Epoch 53/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.6874 - accuracy: 0.8150 - val_loss: 0.7650 - val_accuracy: 0.8113 - lr: 1.0000e-04
# Epoch 54/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.6479 - accuracy: 0.8214 - val_loss: 0.7464 - val_accuracy: 0.8396 - lr: 1.0000e-04
# Epoch 55/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.6403 - accuracy: 0.8372 - val_loss: 0.7281 - val_accuracy: 0.8396 - lr: 1.0000e-04
# Epoch 56/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.6003 - accuracy: 0.8372 - val_loss: 0.7094 - val_accuracy: 0.8396 - lr: 1.0000e-04
# Epoch 57/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.5887 - accuracy: 0.8552 - val_loss: 0.6892 - val_accuracy: 0.8491 - lr: 1.0000e-04
# Epoch 58/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.5570 - accuracy: 0.8531 - val_loss: 0.6686 - val_accuracy: 0.8491 - lr: 1.0000e-04
# Epoch 59/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.5543 - accuracy: 0.8594 - val_loss: 0.6516 - val_accuracy: 0.8679 - lr: 1.0000e-04
# Epoch 60/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.5358 - accuracy: 0.8721 - val_loss: 0.6320 - val_accuracy: 0.8585 - lr: 1.0000e-04
# Epoch 61/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.5143 - accuracy: 0.8647 - val_loss: 0.6187 - val_accuracy: 0.8679 - lr: 1.0000e-04
# Epoch 62/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.4893 - accuracy: 0.8869 - val_loss: 0.6013 - val_accuracy: 0.8774 - lr: 1.0000e-04
# Epoch 63/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.4810 - accuracy: 0.8848 - val_loss: 0.5833 - val_accuracy: 0.8679 - lr: 1.0000e-04
# Epoch 64/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.4695 - accuracy: 0.8848 - val_loss: 0.5681 - val_accuracy: 0.8774 - lr: 1.0000e-04
# Epoch 65/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.4595 - accuracy: 0.8964 - val_loss: 0.5562 - val_accuracy: 0.8774 - lr: 1.0000e-04
# Epoch 66/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.4492 - accuracy: 0.8816 - val_loss: 0.5390 - val_accuracy: 0.8868 - lr: 1.0000e-04
# Epoch 67/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.4263 - accuracy: 0.9038 - val_loss: 0.5272 - val_accuracy: 0.8774 - lr: 1.0000e-04
# Epoch 68/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.4302 - accuracy: 0.8932 - val_loss: 0.5147 - val_accuracy: 0.8868 - lr: 1.0000e-04
# Epoch 69/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3904 - accuracy: 0.9154 - val_loss: 0.4974 - val_accuracy: 0.8962 - lr: 1.0000e-04
# Epoch 70/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3954 - accuracy: 0.9017 - val_loss: 0.4883 - val_accuracy: 0.8962 - lr: 1.0000e-04
# Epoch 71/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3881 - accuracy: 0.9154 - val_loss: 0.4804 - val_accuracy: 0.8868 - lr: 1.0000e-04
# Epoch 72/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3715 - accuracy: 0.9197 - val_loss: 0.4674 - val_accuracy: 0.8962 - lr: 1.0000e-04
# Epoch 73/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3598 - accuracy: 0.9091 - val_loss: 0.4603 - val_accuracy: 0.9057 - lr: 1.0000e-04
# Epoch 74/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3501 - accuracy: 0.9260 - val_loss: 0.4407 - val_accuracy: 0.8962 - lr: 1.0000e-04
# Epoch 75/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3480 - accuracy: 0.9249 - val_loss: 0.4313 - val_accuracy: 0.9245 - lr: 1.0000e-04
# Epoch 76/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3301 - accuracy: 0.9313 - val_loss: 0.4192 - val_accuracy: 0.9151 - lr: 1.0000e-04
# Epoch 77/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3249 - accuracy: 0.9345 - val_loss: 0.4108 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 78/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3119 - accuracy: 0.9334 - val_loss: 0.4008 - val_accuracy: 0.9151 - lr: 1.0000e-04
# Epoch 79/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3022 - accuracy: 0.9366 - val_loss: 0.3917 - val_accuracy: 0.9245 - lr: 1.0000e-04
# Epoch 80/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3001 - accuracy: 0.9408 - val_loss: 0.3842 - val_accuracy: 0.9151 - lr: 1.0000e-04
# Epoch 81/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2731 - accuracy: 0.9450 - val_loss: 0.3786 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 82/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2838 - accuracy: 0.9429 - val_loss: 0.3673 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 83/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2861 - accuracy: 0.9397 - val_loss: 0.3624 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 84/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2647 - accuracy: 0.9461 - val_loss: 0.3562 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 85/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2581 - accuracy: 0.9545 - val_loss: 0.3507 - val_accuracy: 0.9245 - lr: 1.0000e-04
# Epoch 86/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2476 - accuracy: 0.9524 - val_loss: 0.3424 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 87/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2498 - accuracy: 0.9503 - val_loss: 0.3321 - val_accuracy: 0.9245 - lr: 1.0000e-04
# Epoch 88/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2362 - accuracy: 0.9577 - val_loss: 0.3288 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 89/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2367 - accuracy: 0.9619 - val_loss: 0.3212 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 90/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2346 - accuracy: 0.9535 - val_loss: 0.3177 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 91/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2159 - accuracy: 0.9641 - val_loss: 0.3096 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 92/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2090 - accuracy: 0.9641 - val_loss: 0.3047 - val_accuracy: 0.9245 - lr: 1.0000e-04
# Epoch 93/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2090 - accuracy: 0.9641 - val_loss: 0.2978 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 94/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1973 - accuracy: 0.9715 - val_loss: 0.2894 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 95/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1948 - accuracy: 0.9757 - val_loss: 0.2884 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 96/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1922 - accuracy: 0.9651 - val_loss: 0.2833 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 97/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1777 - accuracy: 0.9778 - val_loss: 0.2768 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 98/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1813 - accuracy: 0.9672 - val_loss: 0.2760 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 99/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1808 - accuracy: 0.9577 - val_loss: 0.2668 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 100/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1693 - accuracy: 0.9757 - val_loss: 0.2627 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 101/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1699 - accuracy: 0.9757 - val_loss: 0.2597 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 102/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1571 - accuracy: 0.9799 - val_loss: 0.2541 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 103/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1516 - accuracy: 0.9725 - val_loss: 0.2520 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 104/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1507 - accuracy: 0.9746 - val_loss: 0.2508 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 105/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1582 - accuracy: 0.9736 - val_loss: 0.2427 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 106/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1454 - accuracy: 0.9799 - val_loss: 0.2399 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 107/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1367 - accuracy: 0.9841 - val_loss: 0.2337 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 108/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1334 - accuracy: 0.9810 - val_loss: 0.2298 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 109/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1350 - accuracy: 0.9841 - val_loss: 0.2292 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 110/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1297 - accuracy: 0.9810 - val_loss: 0.2246 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 111/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1344 - accuracy: 0.9778 - val_loss: 0.2250 - val_accuracy: 0.9245 - lr: 1.0000e-04
# Epoch 112/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1238 - accuracy: 0.9810 - val_loss: 0.2192 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 113/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1294 - accuracy: 0.9810 - val_loss: 0.2185 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 114/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1157 - accuracy: 0.9884 - val_loss: 0.2197 - val_accuracy: 0.9245 - lr: 1.0000e-04
# Epoch 115/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1123 - accuracy: 0.9873 - val_loss: 0.2117 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 116/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1075 - accuracy: 0.9873 - val_loss: 0.2083 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 117/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1120 - accuracy: 0.9799 - val_loss: 0.2046 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 118/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1051 - accuracy: 0.9841 - val_loss: 0.2030 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 119/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0926 - accuracy: 0.9884 - val_loss: 0.2038 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 120/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1039 - accuracy: 0.9841 - val_loss: 0.1955 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 121/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1081 - accuracy: 0.9820 - val_loss: 0.1942 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 122/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0966 - accuracy: 0.9905 - val_loss: 0.1934 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 123/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0930 - accuracy: 0.9905 - val_loss: 0.1890 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 124/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0990 - accuracy: 0.9841 - val_loss: 0.1890 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 125/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1007 - accuracy: 0.9799 - val_loss: 0.1824 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 126/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0935 - accuracy: 0.9873 - val_loss: 0.1868 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 127/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0929 - accuracy: 0.9841 - val_loss: 0.1839 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 128/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0832 - accuracy: 0.9894 - val_loss: 0.1788 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 129/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0937 - accuracy: 0.9884 - val_loss: 0.1771 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 130/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0851 - accuracy: 0.9905 - val_loss: 0.1777 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 131/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0806 - accuracy: 0.9905 - val_loss: 0.1729 - val_accuracy: 0.9340 - lr: 1.0000e-04
# Epoch 132/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0775 - accuracy: 0.9905 - val_loss: 0.1708 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 133/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0755 - accuracy: 0.9915 - val_loss: 0.1680 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 134/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0739 - accuracy: 0.9937 - val_loss: 0.1673 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 135/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0694 - accuracy: 0.9968 - val_loss: 0.1659 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 136/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0710 - accuracy: 0.9926 - val_loss: 0.1610 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 137/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0634 - accuracy: 0.9937 - val_loss: 0.1612 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 138/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0722 - accuracy: 0.9926 - val_loss: 0.1595 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 139/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0793 - accuracy: 0.9884 - val_loss: 0.1603 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 140/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0664 - accuracy: 0.9958 - val_loss: 0.1568 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 141/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0652 - accuracy: 0.9915 - val_loss: 0.1549 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 142/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0639 - accuracy: 0.9958 - val_loss: 0.1531 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 143/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0626 - accuracy: 0.9937 - val_loss: 0.1516 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 144/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0620 - accuracy: 0.9905 - val_loss: 0.1507 - val_accuracy: 0.9434 - lr: 1.0000e-04
# Epoch 145/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0609 - accuracy: 0.9926 - val_loss: 0.1523 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 146/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0616 - accuracy: 0.9937 - val_loss: 0.1494 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 147/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0590 - accuracy: 0.9947 - val_loss: 0.1511 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 148/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0631 - accuracy: 0.9947 - val_loss: 0.1434 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 149/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0560 - accuracy: 0.9937 - val_loss: 0.1429 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 150/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0530 - accuracy: 0.9926 - val_loss: 0.1445 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 151/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0572 - accuracy: 0.9947 - val_loss: 0.1408 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 152/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0535 - accuracy: 0.9937 - val_loss: 0.1397 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 153/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0473 - accuracy: 0.9947 - val_loss: 0.1396 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 154/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0517 - accuracy: 0.9926 - val_loss: 0.1412 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 155/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0490 - accuracy: 0.9958 - val_loss: 0.1419 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 156/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0467 - accuracy: 0.9947 - val_loss: 0.1347 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 157/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0585 - accuracy: 0.9905 - val_loss: 0.1339 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 158/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0472 - accuracy: 0.9947 - val_loss: 0.1306 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 159/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0525 - accuracy: 0.9915 - val_loss: 0.1323 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 160/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0459 - accuracy: 0.9958 - val_loss: 0.1317 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 161/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0477 - accuracy: 0.9915 - val_loss: 0.1354 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 162/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0488 - accuracy: 0.9947 - val_loss: 0.1329 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 163/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0459 - accuracy: 0.9968 - val_loss: 0.1281 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 164/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0486 - accuracy: 0.9926 - val_loss: 0.1287 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 165/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0441 - accuracy: 0.9947 - val_loss: 0.1275 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 166/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0419 - accuracy: 0.9947 - val_loss: 0.1236 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 167/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0408 - accuracy: 0.9958 - val_loss: 0.1230 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 168/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0438 - accuracy: 0.9937 - val_loss: 0.1230 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 169/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0384 - accuracy: 0.9937 - val_loss: 0.1226 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 170/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0391 - accuracy: 0.9979 - val_loss: 0.1251 - val_accuracy: 0.9717 - lr: 1.0000e-04
# Epoch 171/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0433 - accuracy: 0.9947 - val_loss: 0.1225 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 172/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0375 - accuracy: 0.9968 - val_loss: 0.1213 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 173/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0419 - accuracy: 0.9947 - val_loss: 0.1163 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 174/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0396 - accuracy: 0.9947 - val_loss: 0.1204 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 175/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0334 - accuracy: 0.9968 - val_loss: 0.1211 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 176/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0364 - accuracy: 0.9989 - val_loss: 0.1172 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 177/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0409 - accuracy: 0.9947 - val_loss: 0.1190 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 178/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0388 - accuracy: 0.9947 - val_loss: 0.1202 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 179/200
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0341 - accuracy: 0.9958 - val_loss: 0.1151 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 180/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0373 - accuracy: 0.9968 - val_loss: 0.1096 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 181/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0360 - accuracy: 0.9979 - val_loss: 0.1119 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 182/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0329 - accuracy: 0.9968 - val_loss: 0.1113 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 183/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0330 - accuracy: 0.9979 - val_loss: 0.1104 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 184/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0373 - accuracy: 0.9958 - val_loss: 0.1164 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 185/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0295 - accuracy: 0.9968 - val_loss: 0.1082 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 186/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 0.9958 - val_loss: 0.1123 - val_accuracy: 0.9717 - lr: 1.0000e-04
# Epoch 187/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0316 - accuracy: 0.9958 - val_loss: 0.1098 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 188/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0318 - accuracy: 0.9968 - val_loss: 0.1065 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 189/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0345 - accuracy: 0.9947 - val_loss: 0.1138 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 190/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0260 - accuracy: 0.9989 - val_loss: 0.1098 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 191/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0280 - accuracy: 0.9979 - val_loss: 0.1090 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 192/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0278 - accuracy: 0.9989 - val_loss: 0.1120 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 193/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0282 - accuracy: 0.9979 - val_loss: 0.1050 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 194/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0281 - accuracy: 0.9968 - val_loss: 0.1062 - val_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 195/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0320 - accuracy: 0.9979 - val_loss: 0.1083 - val_accuracy: 0.9717 - lr: 1.0000e-04
# Epoch 196/200
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0271 - accuracy: 0.9968 - val_loss: 0.1000 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 197/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0237 - accuracy: 0.9989 - val_loss: 0.1006 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 198/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0263 - accuracy: 0.9989 - val_loss: 0.1014 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 199/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0267 - accuracy: 0.9958 - val_loss: 0.1041 - val_accuracy: 0.9623 - lr: 1.0000e-04
# Epoch 200/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0240 - accuracy: 0.9968 - val_loss: 0.1016 - val_accuracy: 0.9623 - lr: 1.0000e-04

# %%
train_val_graph(hist, "accuracy")
train_val_graph(hist, "loss")

# %%
import pickle
pickle.dump(encoder, open("encoder.pkl", "wb"))
pickle.dump({'config': vectorizer.get_config(), 'weights': vectorizer.get_weights()}, open("vectoriser.pkl", "wb"))

# %%
def get_e2e_model(m):
    input_str = keras.Input(shape=(1,), dtype="string")

    x = vectorizer(input_str)  # vectorize

    output = m(x)

    e2e = keras.Model(input_str, output)

    return e2e

# %%
from keras.models import load_model, save_model

model = load_model('intents.h5')
e2e_model = get_e2e_model(model)

# %%
test_sents = [["i want to talk about today"], ["see ya"], ["yes that is correct"], [
    "let's stop talking"], ["that's not right"], ["not quite"], ['tell me what i did yesterday'],
    ['tell me about yesterday'], ['what happened on wednesday'], ['what time is it'], ["order pizza to my house please"]]

for sentence in test_sents:
    sentence[0] = lower(sentence[0])
    sentence[0] = remove_nums(sentence[0])
    sentence[0] = remove_punc(sentence[0])

probabilities = e2e_model.predict(test_sents)

for i in tf.range(len(probabilities)):
    print("The input '" +test_sents[i][0] + "' is labelled with the intent \"" + label_names[np.argmax(probabilities[i])] 
    + "\" with " + str(float('{0:.2f}'.format(np.max(probabilities[i])*100))) + "% certainty")
# Out:
# The input 'i want to talk about today' is labelled with the intent "add_entry" with 99.94% certainty
# The input 'see ya' is labelled with the intent "goodbye" with 98.14% certainty
# The input 'yes that is correct' is labelled with the intent "yes" with 99.49% certainty
# The input 'lets stop talking' is labelled with the intent "goodbye" with 100.0% certainty
# The input 'thats not right' is labelled with the intent "no" with 95.13% certainty
# The input 'not quite' is labelled with the intent "no" with 98.99% certainty
# The input 'tell me what i did yesterday' is labelled with the intent "entry_query" with 99.52% certainty
# The input 'tell me about yesterday' is labelled with the intent "entry_query" with 97.04% certainty
# The input 'what happened on wednesday' is labelled with the intent "entry_query" with 99.56% certainty
# The input 'what time is it' is labelled with the intent "oos" with 97.5% certainty
# The input 'order pizza to my house please' is labelled with the intent "oos" with 93.53% certainty
